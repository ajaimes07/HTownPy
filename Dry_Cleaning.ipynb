# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import string as string
csv_path = "Desktop/DC_Registration_All.csv"
dryclean_df = pd.read_csv(csv_path)
dryclean_df.head()
# Out:
#   LGL_IDENT_TXT           RN              REG_ENT_NAME  \
# 0      DCR12618  RN100528066  PATRICK CARR EXXON 62764
# 1      DCR10063  RN100543339           BAKERS CLEANERS
# 2      DCR10065  RN100544741  VIP CLEANERS - TROUP HWY
# 3      DCR10066  RN100544758          NORMANS CLEANERS
# 4      DCR10067  RN100544956         OAK PARK CLEANERS
#
#                   DELIV_TXT  DELIV_2_TXT    CITY_NAME USPS_STATE_CD   ZIP_CD  \
# 0          10650 AUDELIA RD          NaN       DALLAS            TX  75238.0
# 1              8447 PARK LN          NaN       DALLAS            TX  75231.0
# 2            4723 TROUP HWY          NaN        TYLER            TX  75703.0
# 3               1031 4TH ST          NaN       GRAHAM            TX  76450.0
# 4  300 W BITTERS RD STE 100          NaN  SAN ANTONIO            TX  78216.0
#
#    ZIP_PLUS4_CD  COUNTY  ... PHONE_AREA_CD PHONE_NUM         PHYS_NAME  \
# 0        1066.0  DALLAS  ...           214   3423777  DOUGLAS CLEANERS
# 1        6307.0  DALLAS  ...           214   3630990   BAKERS CLEANERS
# 2        2307.0   SMITH  ...           903   5665330               NaN
# 3        3207.0   YOUNG  ...           940   5214423               NaN
# 4        1676.0   BEXAR  ...           210   2124448               NaN
#
#                   LGL_TYP_CD LGL_STATUS_CD LGL_DESC_TXT    SOLVENT  GALLONS  \
# 0      FACILITY REGISTRATION        ACTIVE       FY2019  PETROLEUM     50.0
# 1      FACILITY REGISTRATION        ACTIVE       FY2019      OTHER      1.0
# 2  DROP STATION REGISTRATION        ACTIVE       FY2019        NaN      NaN
# 3      FACILITY REGISTRATION        ACTIVE       FY2019        NaN      NaN
# 4  DROP STATION REGISTRATION        ACTIVE       FY2019        NaN      NaN
#
#    ELIGIBLEANSWER GROSSRECEIPTAMOUNT
# 0             YES         > $150,000
# 1             YES   $150,000 OR LESS
# 2             YES   $150,000 OR LESS
# 3             YES   $150,000 OR LESS
# 4             YES         > $150,000
#
# [5 rows x 30 columns]

# %%
#dropping columns that wont be used to tell us anything
dryclean_df = dryclean_df[["REG_ENT_NAME", "CITY_NAME", "ZIP_CD", "COUNTY", "PHYS_NAME"]]
dryclean_df.head()
# Out:
#                REG_ENT_NAME    CITY_NAME   ZIP_CD  COUNTY         PHYS_NAME
# 0  PATRICK CARR EXXON 62764       DALLAS  75238.0  DALLAS  DOUGLAS CLEANERS
# 1           BAKERS CLEANERS       DALLAS  75231.0  DALLAS   BAKERS CLEANERS
# 2  VIP CLEANERS - TROUP HWY        TYLER  75703.0   SMITH               NaN
# 3          NORMANS CLEANERS       GRAHAM  76450.0   YOUNG               NaN
# 4         OAK PARK CLEANERS  SAN ANTONIO  78216.0   BEXAR               NaN

# %%
#Output cleaned data to csv
#housepy_df.to_csv("housepy_cleaned.csv", index=False, header=True)

# %%
#Clean data for no value cells

dryclean_df.dtypes

dryclean_df.dropna(inplace=True)

# %%
#df.a = df.a.astype(float)

dryclean_df['ZIP_CD'] = dryclean_df['ZIP_CD'].astype(int)
dryclean_df.head()
# Out:
#                 REG_ENT_NAME    CITY_NAME  ZIP_CD     COUNTY  \
# 0   PATRICK CARR EXXON 62764       DALLAS   75238     DALLAS
# 1            BAKERS CLEANERS       DALLAS   75231     DALLAS
# 6  WORTHINGTON LAUNDRY & CLN  SAN ANTONIO   78215      BEXAR
# 7       BRITE TOUCH CLEANERS   SUGAR LAND   77478  FORT BEND
# 8          LAKESIDE CLEANERS       DALLAS   75231     DALLAS
#
#                    PHYS_NAME
# 0           DOUGLAS CLEANERS
# 1            BAKERS CLEANERS
# 6  WORTHINGTON LAUNDRY & CLN
# 7       BRITE TOUCH CLEANERS
# 8          LAKESIDE CLEANERS

# %%
dryclean_df['COUNTY'] = dryclean_df['COUNTY'].astype(str)

# %%
dryclean_df.dtypes
# Out:
# REG_ENT_NAME    object
# CITY_NAME       object
# ZIP_CD           int32
# COUNTY          object
# PHYS_NAME       object
# dtype: object

# %%
DRYCLEAN1 = dryclean_df[dryclean_df["COUNTY"]=="BRAZORIA"]

DRYCLEAN1.reset_index(inplace=True)

DRYCLEAN1.head()
# Out:
#    index           REG_ENT_NAME     CITY_NAME  ZIP_CD    COUNTY  \
# 0     71    CULLEN DRY CLEANERS      PEARLAND   77581  BRAZORIA
# 1     85       FRAKEYS CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 2    531          BEST CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 3    542  EXPRESS 1.59 CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 4    554        K & T DRY CLEAN      PEARLAND   77581  BRAZORIA
#
#                 PHYS_NAME
# 0     CULLEN DRY CLEANERS
# 1        FRAKEYS CLEANERS
# 2           BEST CLEANERS
# 3   EXPRESS 1.59 CLEANERS
# 4  DRY CLEAN SUPER CENTER

# %%
DRYCLEAN2 = dryclean_df[dryclean_df["COUNTY"]=="BRAZOS"]

DRYCLEAN2.reset_index(inplace=True)

DRYCLEAN2.head()
# Out:
#    index          REG_ENT_NAME        CITY_NAME  ZIP_CD  COUNTY  \
# 0     46  VILLA MARIA CLEANERS            BRYAN   77802  BRAZOS
# 1    360          PRO CLEANERS  COLLEGE STATION   77840  BRAZOS
# 2    514       JOT 59 CLEANERS  COLLEGE STATION   77840  BRAZOS
# 3    515       JOT 59 CLEANERS  COLLEGE STATION   77840  BRAZOS
# 4    666   BRIARCREST CLEANERS            BRYAN   77802  BRAZOS
#
#               PHYS_NAME
# 0  VILLA MARIA CLEANERS
# 1          PRO CLEANERS
# 2       JOT 59 CLEANERS
# 3       JOT 59 CLEANERS
# 4   BRIARCREST CLEANERS

# %%
DRYCLEAN3 = dryclean_df[dryclean_df["COUNTY"]=="FORT BEND"]

DRYCLEAN3.reset_index(inplace=True)

DRYCLEAN3.head()
# Out:
#    index          REG_ENT_NAME      CITY_NAME  ZIP_CD     COUNTY  \
# 0      7  BRITE TOUCH CLEANERS     SUGAR LAND   77478  FORT BEND
# 1     43  CONTINENTAL CLEANERS     SUGAR LAND   77478  FORT BEND
# 2    140        QUAIL CLEANERS  MISSOURI CITY   77459  FORT BEND
# 3    165  CRABB RIVER CLEANERS       RICHMOND   77469  FORT BEND
# 4    209      QUALITY CLEANERS       STAFFORD   77477  FORT BEND
#
#               PHYS_NAME
# 0  BRITE TOUCH CLEANERS
# 1  CONTINENTAL CLEANERS
# 2        QUAIL CLEANERS
# 3  CRABB RIVER CLEANERS
# 4      QUALITY CLEANERS

# %%
DRYCLEAN4 = dryclean_df[dryclean_df["COUNTY"]=="GALVESTON"]

DRYCLEAN4.reset_index(inplace=True)

DRYCLEAN4.head()
# Out:
#    index            REG_ENT_NAME    CITY_NAME  ZIP_CD     COUNTY  \
# 0     80    SOUTH SHORE CLEANERS  LEAGUE CITY   77573  GALVESTON
# 1    201        QUALITY CLEANERS    GALVESTON   77551  GALVESTON
# 2    224  T&C SPECIALTY CLEANERS   TEXAS CITY   77590  GALVESTON
# 3    305          B & H CLEANERS    GALVESTON   77550  GALVESTON
# 4    322     ENTERPRISE CLEANERS  LEAGUE CITY   77573  GALVESTON
#
#                 PHYS_NAME
# 0    SOUTH SHORE CLEANERS
# 1        QUALITY CLEANERS
# 2  T&C SPECIALTY CLEANERS
# 3          B & H CLEANERS
# 4     ENTERPRISE CLEANERS

# %%
DRYCLEAN5 = dryclean_df[dryclean_df["COUNTY"]=="HARRIS"]

DRYCLEAN5.reset_index(inplace=True)

DRYCLEAN5.head()
# Out:
#    index           REG_ENT_NAME CITY_NAME  ZIP_CD  COUNTY  \
# 0     14         WOLFE CLEANERS   HOUSTON   77007  HARRIS
# 1     19    YOUR VALET CLEANERS   HOUSTON   77091  HARRIS
# 2     22        UPTOWN CLEANERS   HOUSTON   77057  HARRIS
# 3     24       PREMIER CLEANERS   HOUSTON   77079  HARRIS
# 4     25  DELUXE DRY CLEANERS 1   CYPRESS   77429  HARRIS
#
#                PHYS_NAME
# 0         WOLFE CLEANERS
# 1    YOUR VALET CLEANERS
# 2        UPTOWN CLEANERS
# 3       PREMIER CLEANERS
# 4  DELUXE DRY CLEANERS 1

# %%
DRYCLEAN6 = dryclean_df[dryclean_df["COUNTY"]=="MONTGOMERY"]

DRYCLEAN6.reset_index(inplace=True)

DRYCLEAN6.head()
# Out:
#    index                      REG_ENT_NAME      CITY_NAME  ZIP_CD      COUNTY  \
# 0    251                   SPEEDY CLEANERS         CONROE   77304  MONTGOMERY
# 1    315  SIGNATURE LAUNDRY & DRY CLEANERS         CONROE   77301  MONTGOMERY
# 2    335                 LIVE OAK CLEANERS         CONROE   77304  MONTGOMERY
# 3    479                 MW CLEANERS 10003  THE WOODLANDS   77381  MONTGOMERY
# 4    480                 MW CLEANERS 10005  THE WOODLANDS   77382  MONTGOMERY
#
#                           PHYS_NAME
# 0                   SPEEDY CLEANERS
# 1  SIGNATURE LAUNDRY & DRY CLEANERS
# 2                 LIVE OAK CLEANERS
# 3           TIDE DRY CLEANERS 10003
# 4           TIDE DRY CLEANERS 10005

# %%
#Rmerge_math_score = pd.merge(Rninth_grade_df, Rtenth_grade_df, on="school_name")
#pd.merge(df1, df2, on = ['Name', 'Parent', 'Parent_Addr'], how = 'outer')

merge1 = pd.merge(DRYCLEAN1, DRYCLEAN2, on = ['REG_ENT_NAME', 'CITY_NAME', 'ZIP_CD', 'COUNTY', 'PHYS_NAME'], how= 'outer')
merge1.head()
# Out:
#    index_x           REG_ENT_NAME     CITY_NAME  ZIP_CD    COUNTY  \
# 0     71.0    CULLEN DRY CLEANERS      PEARLAND   77581  BRAZORIA
# 1     85.0       FRAKEYS CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 2    531.0          BEST CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 3    542.0  EXPRESS 1.59 CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 4    554.0        K & T DRY CLEAN      PEARLAND   77581  BRAZORIA
#
#                 PHYS_NAME  index_y
# 0     CULLEN DRY CLEANERS      NaN
# 1        FRAKEYS CLEANERS      NaN
# 2           BEST CLEANERS      NaN
# 3   EXPRESS 1.59 CLEANERS      NaN
# 4  DRY CLEAN SUPER CENTER      NaN

# %%
merge2 = pd.merge(merge1, DRYCLEAN3, on = ['REG_ENT_NAME', 'CITY_NAME', 'ZIP_CD', 'COUNTY', 'PHYS_NAME'], how= 'outer')
merge2.head()
# Out:
#    index_x           REG_ENT_NAME     CITY_NAME  ZIP_CD    COUNTY  \
# 0     71.0    CULLEN DRY CLEANERS      PEARLAND   77581  BRAZORIA
# 1     85.0       FRAKEYS CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 2    531.0          BEST CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 3    542.0  EXPRESS 1.59 CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 4    554.0        K & T DRY CLEAN      PEARLAND   77581  BRAZORIA
#
#                 PHYS_NAME  index_y  index
# 0     CULLEN DRY CLEANERS      NaN    NaN
# 1        FRAKEYS CLEANERS      NaN    NaN
# 2           BEST CLEANERS      NaN    NaN
# 3   EXPRESS 1.59 CLEANERS      NaN    NaN
# 4  DRY CLEAN SUPER CENTER      NaN    NaN

# %%
merge3 = pd.merge(merge2, DRYCLEAN4, on = ['REG_ENT_NAME', 'CITY_NAME', 'ZIP_CD', 'COUNTY', 'PHYS_NAME'], how= 'outer')
merge3.head()
# Out:
#    index_x           REG_ENT_NAME     CITY_NAME  ZIP_CD    COUNTY  \
# 0     71.0    CULLEN DRY CLEANERS      PEARLAND   77581  BRAZORIA
# 1     85.0       FRAKEYS CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 2    531.0          BEST CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 3    542.0  EXPRESS 1.59 CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 4    554.0        K & T DRY CLEAN      PEARLAND   77581  BRAZORIA
#
#                 PHYS_NAME  index_y  index_x  index_y
# 0     CULLEN DRY CLEANERS      NaN      NaN      NaN
# 1        FRAKEYS CLEANERS      NaN      NaN      NaN
# 2           BEST CLEANERS      NaN      NaN      NaN
# 3   EXPRESS 1.59 CLEANERS      NaN      NaN      NaN
# 4  DRY CLEAN SUPER CENTER      NaN      NaN      NaN

# %%
merge4 = pd.merge(merge3, DRYCLEAN5, on = ['REG_ENT_NAME', 'CITY_NAME', 'ZIP_CD', 'COUNTY', 'PHYS_NAME'], how= 'outer')
merge4.head()
# Out:
#    index_x           REG_ENT_NAME     CITY_NAME  ZIP_CD    COUNTY  \
# 0     71.0    CULLEN DRY CLEANERS      PEARLAND   77581  BRAZORIA
# 1     85.0       FRAKEYS CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 2    531.0          BEST CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 3    542.0  EXPRESS 1.59 CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 4    554.0        K & T DRY CLEAN      PEARLAND   77581  BRAZORIA
#
#                 PHYS_NAME  index_y  index_x  index_y  index
# 0     CULLEN DRY CLEANERS      NaN      NaN      NaN    NaN
# 1        FRAKEYS CLEANERS      NaN      NaN      NaN    NaN
# 2           BEST CLEANERS      NaN      NaN      NaN    NaN
# 3   EXPRESS 1.59 CLEANERS      NaN      NaN      NaN    NaN
# 4  DRY CLEAN SUPER CENTER      NaN      NaN      NaN    NaN

# %%
merge5 = pd.merge(merge4, DRYCLEAN6, on = ['REG_ENT_NAME', 'CITY_NAME', 'ZIP_CD', 'COUNTY', 'PHYS_NAME'], how= 'outer')
merge5.head()
# Out:
#    index_x           REG_ENT_NAME     CITY_NAME  ZIP_CD    COUNTY  \
# 0     71.0    CULLEN DRY CLEANERS      PEARLAND   77581  BRAZORIA
# 1     85.0       FRAKEYS CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 2    531.0          BEST CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 3    542.0  EXPRESS 1.59 CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 4    554.0        K & T DRY CLEAN      PEARLAND   77581  BRAZORIA
#
#                 PHYS_NAME  index_y  index_x  index_y  index_x  index_y
# 0     CULLEN DRY CLEANERS      NaN      NaN      NaN      NaN      NaN
# 1        FRAKEYS CLEANERS      NaN      NaN      NaN      NaN      NaN
# 2           BEST CLEANERS      NaN      NaN      NaN      NaN      NaN
# 3   EXPRESS 1.59 CLEANERS      NaN      NaN      NaN      NaN      NaN
# 4  DRY CLEAN SUPER CENTER      NaN      NaN      NaN      NaN      NaN

# %%
merge5 = merge5[["REG_ENT_NAME", "CITY_NAME", "ZIP_CD", "COUNTY", "PHYS_NAME"]]
merge5.head()
# Out:
#             REG_ENT_NAME     CITY_NAME  ZIP_CD    COUNTY  \
# 0    CULLEN DRY CLEANERS      PEARLAND   77581  BRAZORIA
# 1       FRAKEYS CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 2          BEST CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 3  EXPRESS 1.59 CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 4        K & T DRY CLEAN      PEARLAND   77581  BRAZORIA
#
#                 PHYS_NAME
# 0     CULLEN DRY CLEANERS
# 1        FRAKEYS CLEANERS
# 2           BEST CLEANERS
# 3   EXPRESS 1.59 CLEANERS
# 4  DRY CLEAN SUPER CENTER

# %%
merge5.to_csv('Dryclean_project.csv', index=False, header=True)
