# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import string as string
csv_path = "Desktop/DC_Registration_All.csv"
dryclean_df = pd.read_csv(csv_path)
dryclean_df.head()
# Out:
#   LGL_IDENT_TXT           RN            REG_ENT_NAME         DELIV_TXT  \
# 0      DCR12201  RN103970422  DRY CLEAN SUPER CENTER  1733 CROCKETT RD
# 1      DCR12814  RN104059860           CITY CLEANERS   200 COMMERCE ST
# 2      DCR13615  RN104103270  VIP CLEANERS-PALESTINE  2019 CROCKETT RD
# 3      DCR15044  RN105481618          RITAS CLEANERS    1420 NE 7TH ST
# 4      DCR16176  RN110600954   ALL AMERICAN CLEANERS     106 S MAIN ST
#
#    DELIV_2_TXT  CITY_NAME USPS_STATE_CD   ZIP_CD  ZIP_PLUS4_CD    COUNTY  ...  \
# 0          NaN  PALESTINE            TX  75801.0        5901.0  ANDERSON  ...
# 1          NaN  FRANKSTON            TX  75763.0        9727.0  ANDERSON  ...
# 2          NaN  PALESTINE            TX  75801.0        5907.0  ANDERSON  ...
# 3          NaN    ANDREWS            TX  79714.0        3626.0   ANDREWS  ...
# 4          NaN    ANDREWS            TX  79714.0        7125.0   ANDREWS  ...
#
# ...

# %%
#dropping columns that wont be used to tell us anything
dryclean_df = dryclean_df[["REG_ENT_NAME", "CITY_NAME", "ZIP_CD", "COUNTY", "PHYS_NAME"]]
dryclean_df.head()
# Out:
#              REG_ENT_NAME  CITY_NAME   ZIP_CD    COUNTY  \
# 0  DRY CLEAN SUPER CENTER  PALESTINE  75801.0  ANDERSON
# 1           CITY CLEANERS  FRANKSTON  75763.0  ANDERSON
# 2  VIP CLEANERS-PALESTINE  PALESTINE  75801.0  ANDERSON
# 3          RITAS CLEANERS    ANDREWS  79714.0   ANDREWS
# 4   ALL AMERICAN CLEANERS    ANDREWS  79714.0   ANDREWS
#
#                 PHYS_NAME
# 0  DRY CLEAN SUPER CENTER
# 1           CITY CLEANERS
# 2  VIP CLEANERS-PALESTINE
# 3          RITAS CLEANERS
# 4                     NaN

# %%
#Output cleaned data to csv
#housepy_df.to_csv("housepy_cleaned.csv", index=False, header=True)

# %%
#Clean data for no value cells

dryclean_df.dtypes

dryclean_df.dropna(inplace=True)

# %%
#df.a = df.a.astype(float)

dryclean_df['ZIP_CD'] = dryclean_df['ZIP_CD'].astype(int)
dryclean_df.head()
# Out:
#              REG_ENT_NAME  CITY_NAME  ZIP_CD    COUNTY               PHYS_NAME
# 0  DRY CLEAN SUPER CENTER  PALESTINE   75801  ANDERSON  DRY CLEAN SUPER CENTER
# 1           CITY CLEANERS  FRANKSTON   75763  ANDERSON           CITY CLEANERS
# 2  VIP CLEANERS-PALESTINE  PALESTINE   75801  ANDERSON  VIP CLEANERS-PALESTINE
# 3          RITAS CLEANERS    ANDREWS   79714   ANDREWS          RITAS CLEANERS
# 5        REGENCY CLEANERS     LUFKIN   75904  ANGELINA        REGENCY CLEANERS

# %%
dryclean_df['COUNTY'] = dryclean_df['COUNTY'].astype(str)

# %%
dryclean_df.dtypes
# Out:
# REG_ENT_NAME    object
# CITY_NAME       object
# ZIP_CD           int32
# COUNTY          object
# PHYS_NAME       object
# dtype: object

# %%
DRYCLEAN1 = dryclean_df[dryclean_df["COUNTY"]=="BRAZORIA"]

DRYCLEAN1.reset_index(inplace=True)

DRYCLEAN1.head()
# Out:
#    index           REG_ENT_NAME     CITY_NAME  ZIP_CD    COUNTY  \
# 0    216    CULLEN DRY CLEANERS      PEARLAND   77581  BRAZORIA
# 1    217       FRAKEYS CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 2    218          BEST CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 3    219  EXPRESS 1.59 CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 4    220        K & T DRY CLEAN      PEARLAND   77581  BRAZORIA
#
#                 PHYS_NAME
# 0     CULLEN DRY CLEANERS
# 1        FRAKEYS CLEANERS
# 2           BEST CLEANERS
# 3   EXPRESS 1.59 CLEANERS
# 4  DRY CLEAN SUPER CENTER

# %%
DRYCLEAN2 = dryclean_df[dryclean_df["COUNTY"]=="BRAZOS"]

DRYCLEAN2.reset_index(inplace=True)

DRYCLEAN2.head()
# Out:
#    index          REG_ENT_NAME        CITY_NAME  ZIP_CD  COUNTY  \
# 0    250  VILLA MARIA CLEANERS            BRYAN   77802  BRAZOS
# 1    251          PRO CLEANERS  COLLEGE STATION   77840  BRAZOS
# 2    252       JOT 59 CLEANERS  COLLEGE STATION   77840  BRAZOS
# 3    253       JOT 59 CLEANERS  COLLEGE STATION   77840  BRAZOS
# 4    254   BRIARCREST CLEANERS            BRYAN   77802  BRAZOS
#
#               PHYS_NAME
# 0  VILLA MARIA CLEANERS
# 1          PRO CLEANERS
# 2       JOT 59 CLEANERS
# 3       JOT 59 CLEANERS
# 4   BRIARCREST CLEANERS

# %%
DRYCLEAN3 = dryclean_df[dryclean_df["COUNTY"]=="FORT BEND"]

DRYCLEAN3.reset_index(inplace=True)

DRYCLEAN3.head()
# Out:
#    index          REG_ENT_NAME      CITY_NAME  ZIP_CD     COUNTY  \
# 0    948  BRITE TOUCH CLEANERS     SUGAR LAND   77478  FORT BEND
# 1    949  CONTINENTAL CLEANERS     SUGAR LAND   77478  FORT BEND
# 2    950        QUAIL CLEANERS  MISSOURI CITY   77459  FORT BEND
# 3    951  CRABB RIVER CLEANERS       RICHMOND   77469  FORT BEND
# 4    952      QUALITY CLEANERS       STAFFORD   77477  FORT BEND
#
#               PHYS_NAME
# 0  BRITE TOUCH CLEANERS
# 1  CONTINENTAL CLEANERS
# 2        QUAIL CLEANERS
# 3  CRABB RIVER CLEANERS
# 4      QUALITY CLEANERS

# %%
DRYCLEAN4 = dryclean_df[dryclean_df["COUNTY"]=="GALVESTON"]

DRYCLEAN4.reset_index(inplace=True)

DRYCLEAN4.head()
# Out:
#    index            REG_ENT_NAME    CITY_NAME  ZIP_CD     COUNTY  \
# 0   1056    SOUTH SHORE CLEANERS  LEAGUE CITY   77573  GALVESTON
# 1   1057        QUALITY CLEANERS    GALVESTON   77551  GALVESTON
# 2   1059  T&C SPECIALTY CLEANERS   TEXAS CITY   77590  GALVESTON
# 3   1060          B & H CLEANERS    GALVESTON   77550  GALVESTON
# 4   1061     ENTERPRISE CLEANERS  LEAGUE CITY   77573  GALVESTON
#
#                 PHYS_NAME
# 0    SOUTH SHORE CLEANERS
# 1        QUALITY CLEANERS
# 2  T&C SPECIALTY CLEANERS
# 3          B & H CLEANERS
# 4     ENTERPRISE CLEANERS

# %%
DRYCLEAN5 = dryclean_df[dryclean_df["COUNTY"]=="HARRIS"]

DRYCLEAN5.reset_index(inplace=True)

DRYCLEAN5.head()
# Out:
#    index           REG_ENT_NAME CITY_NAME  ZIP_CD  COUNTY  \
# 0   1130         WOLFE CLEANERS   HOUSTON   77007  HARRIS
# 1   1131    YOUR VALET CLEANERS   HOUSTON   77091  HARRIS
# 2   1132        UPTOWN CLEANERS   HOUSTON   77057  HARRIS
# 3   1134       PREMIER CLEANERS   HOUSTON   77079  HARRIS
# 4   1135  DELUXE DRY CLEANERS 1   CYPRESS   77429  HARRIS
#
#                PHYS_NAME
# 0         WOLFE CLEANERS
# 1    YOUR VALET CLEANERS
# 2        UPTOWN CLEANERS
# 3       PREMIER CLEANERS
# 4  DELUXE DRY CLEANERS 1

# %%
DRYCLEAN6 = dryclean_df[dryclean_df["COUNTY"]=="MONTGOMERY"]

DRYCLEAN6.reset_index(inplace=True)

DRYCLEAN6.head()
# Out:
#    index                      REG_ENT_NAME      CITY_NAME  ZIP_CD      COUNTY  \
# 0   1903                   SPEEDY CLEANERS         CONROE   77304  MONTGOMERY
# 1   1904  SIGNATURE LAUNDRY & DRY CLEANERS         CONROE   77301  MONTGOMERY
# 2   1905                 LIVE OAK CLEANERS         CONROE   77304  MONTGOMERY
# 3   1907                 MW CLEANERS 10003  THE WOODLANDS   77381  MONTGOMERY
# 4   1908                 MW CLEANERS 10005  THE WOODLANDS   77382  MONTGOMERY
#
#                           PHYS_NAME
# 0                   SPEEDY CLEANERS
# 1  SIGNATURE LAUNDRY & DRY CLEANERS
# 2                 LIVE OAK CLEANERS
# 3           TIDE DRY CLEANERS 10003
# 4           TIDE DRY CLEANERS 10005

# %%
#Rmerge_math_score = pd.merge(Rninth_grade_df, Rtenth_grade_df, on="school_name")
#pd.merge(df1, df2, on = ['Name', 'Parent', 'Parent_Addr'], how = 'outer')

merge1 = pd.merge(DRYCLEAN1, DRYCLEAN2, on = ['REG_ENT_NAME', 'CITY_NAME', 'ZIP_CD', 'COUNTY', 'PHYS_NAME'], how= 'outer')
merge1.head()
# Out:
#    index_x           REG_ENT_NAME     CITY_NAME  ZIP_CD    COUNTY  \
# 0    216.0    CULLEN DRY CLEANERS      PEARLAND   77581  BRAZORIA
# 1    217.0       FRAKEYS CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 2    218.0          BEST CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 3    219.0  EXPRESS 1.59 CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 4    220.0        K & T DRY CLEAN      PEARLAND   77581  BRAZORIA
#
#                 PHYS_NAME  index_y
# 0     CULLEN DRY CLEANERS      NaN
# 1        FRAKEYS CLEANERS      NaN
# 2           BEST CLEANERS      NaN
# 3   EXPRESS 1.59 CLEANERS      NaN
# 4  DRY CLEAN SUPER CENTER      NaN

# %%
merge2 = pd.merge(merge1, DRYCLEAN3, on = ['REG_ENT_NAME', 'CITY_NAME', 'ZIP_CD', 'COUNTY', 'PHYS_NAME'], how= 'outer')
merge2.head()
# Out:
#    index_x           REG_ENT_NAME     CITY_NAME  ZIP_CD    COUNTY  \
# 0    216.0    CULLEN DRY CLEANERS      PEARLAND   77581  BRAZORIA
# 1    217.0       FRAKEYS CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 2    218.0          BEST CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 3    219.0  EXPRESS 1.59 CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 4    220.0        K & T DRY CLEAN      PEARLAND   77581  BRAZORIA
#
#                 PHYS_NAME  index_y  index
# 0     CULLEN DRY CLEANERS      NaN    NaN
# 1        FRAKEYS CLEANERS      NaN    NaN
# 2           BEST CLEANERS      NaN    NaN
# 3   EXPRESS 1.59 CLEANERS      NaN    NaN
# 4  DRY CLEAN SUPER CENTER      NaN    NaN

# %%
merge3 = pd.merge(merge2, DRYCLEAN4, on = ['REG_ENT_NAME', 'CITY_NAME', 'ZIP_CD', 'COUNTY', 'PHYS_NAME'], how= 'outer')
merge3.head()
# Out:
#    index_x           REG_ENT_NAME     CITY_NAME  ZIP_CD    COUNTY  \
# 0    216.0    CULLEN DRY CLEANERS      PEARLAND   77581  BRAZORIA
# 1    217.0       FRAKEYS CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 2    218.0          BEST CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 3    219.0  EXPRESS 1.59 CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 4    220.0        K & T DRY CLEAN      PEARLAND   77581  BRAZORIA
#
#                 PHYS_NAME  index_y  index_x  index_y
# 0     CULLEN DRY CLEANERS      NaN      NaN      NaN
# 1        FRAKEYS CLEANERS      NaN      NaN      NaN
# 2           BEST CLEANERS      NaN      NaN      NaN
# 3   EXPRESS 1.59 CLEANERS      NaN      NaN      NaN
# 4  DRY CLEAN SUPER CENTER      NaN      NaN      NaN

# %%
merge4 = pd.merge(merge3, DRYCLEAN5, on = ['REG_ENT_NAME', 'CITY_NAME', 'ZIP_CD', 'COUNTY', 'PHYS_NAME'], how= 'outer')
merge4.head()
# Out:
#    index_x           REG_ENT_NAME     CITY_NAME  ZIP_CD    COUNTY  \
# 0    216.0    CULLEN DRY CLEANERS      PEARLAND   77581  BRAZORIA
# 1    217.0       FRAKEYS CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 2    218.0          BEST CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 3    219.0  EXPRESS 1.59 CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 4    220.0        K & T DRY CLEAN      PEARLAND   77581  BRAZORIA
#
#                 PHYS_NAME  index_y  index_x  index_y  index
# 0     CULLEN DRY CLEANERS      NaN      NaN      NaN    NaN
# 1        FRAKEYS CLEANERS      NaN      NaN      NaN    NaN
# 2           BEST CLEANERS      NaN      NaN      NaN    NaN
# 3   EXPRESS 1.59 CLEANERS      NaN      NaN      NaN    NaN
# 4  DRY CLEAN SUPER CENTER      NaN      NaN      NaN    NaN

# %%
merge5 = pd.merge(merge4, DRYCLEAN6, on = ['REG_ENT_NAME', 'CITY_NAME', 'ZIP_CD', 'COUNTY', 'PHYS_NAME'], how= 'outer')
merge5.head()
# Out:
#    index_x           REG_ENT_NAME     CITY_NAME  ZIP_CD    COUNTY  \
# 0    216.0    CULLEN DRY CLEANERS      PEARLAND   77581  BRAZORIA
# 1    217.0       FRAKEYS CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 2    218.0          BEST CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 3    219.0  EXPRESS 1.59 CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 4    220.0        K & T DRY CLEAN      PEARLAND   77581  BRAZORIA
#
#                 PHYS_NAME  index_y  index_x  index_y  index_x  index_y
# 0     CULLEN DRY CLEANERS      NaN      NaN      NaN      NaN      NaN
# 1        FRAKEYS CLEANERS      NaN      NaN      NaN      NaN      NaN
# 2           BEST CLEANERS      NaN      NaN      NaN      NaN      NaN
# 3   EXPRESS 1.59 CLEANERS      NaN      NaN      NaN      NaN      NaN
# 4  DRY CLEAN SUPER CENTER      NaN      NaN      NaN      NaN      NaN

# %%
merge5 = merge5[["REG_ENT_NAME", "CITY_NAME", "ZIP_CD", "COUNTY", "PHYS_NAME"]]
merge5.head()
# Out:
#             REG_ENT_NAME     CITY_NAME  ZIP_CD    COUNTY  \
# 0    CULLEN DRY CLEANERS      PEARLAND   77581  BRAZORIA
# 1       FRAKEYS CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 2          BEST CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 3  EXPRESS 1.59 CLEANERS  LAKE JACKSON   77566  BRAZORIA
# 4        K & T DRY CLEAN      PEARLAND   77581  BRAZORIA
#
#                 PHYS_NAME
# 0     CULLEN DRY CLEANERS
# 1        FRAKEYS CLEANERS
# 2           BEST CLEANERS
# 3   EXPRESS 1.59 CLEANERS
# 4  DRY CLEAN SUPER CENTER

# %%
merge5.to_csv('Dryclean_project.csv', index=False, header=True)

# %%
from sqlalchemy import create_engine
connection_string = "etlproj:password@localhost:5432/ETLPROJ"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# []

# %%
merge5.to_sql('dry_cleaning', con=engine)
